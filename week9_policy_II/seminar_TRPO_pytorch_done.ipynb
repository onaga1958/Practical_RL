# %%
# launch XVFB if you run on a server
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
    # !bash ../xvfb start
    # %env DISPLAY=:1
# Out:
# Starting virtual X frame buffer: Xvfb../xvfb: line 8: start-stop-daemon: command not found
# .
# env: DISPLAY=:1

# %% [markdown]
# ### Let's make a TRPO!
#
# In this notebook we will write the code of the one Trust Region Policy Optimization.
# As usually, it contains a few different parts which we are going to reproduce.

# %%
import numpy as np
import torch, torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# %%
import gym
       
env = gym.make("Acrobot-v1")
env.reset()
observation_shape = env.observation_space.shape
n_actions = env.action_space.n
print("Observation Space", env.observation_space)
print("Action Space", env.action_space)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Observation Space Box(6,)
# Action Space Discrete(3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(env.render('rgb_array'))

# %% [markdown]
# ### Step 1: Defining a network
#
# With all it's complexity, at it's core TRPO is yet another policy gradient method.
#
# This essentially means we're actually training a stochastic policy $ \pi_\theta(a|s) $.
#
# And yes, it's gonna be a neural network. So let's start by defining one.

# %%
class TRPOAgent(nn.Module):
    def __init__(self, state_shape, n_actions, hidden_size=32):
        '''
        Here you should define your model
        You should have LOG-PROBABILITIES as output because you will need it to compute loss
        We recommend that you start simple: 
        use 1-2 hidden layers with 100-500 units and relu for the first try
        '''
        nn.Module.__init__(self)
        self.model = nn.Sequential(
            nn.Linear(state_shape[0], hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions),
            nn.LogSoftmax(dim=1)
        )

    def forward(self, states):
        """
        takes agent's observation (Variable), returns log-probabilities (Variable)
        :param state_t: a batch of states, shape = [batch_size, state_shape]
        """
        
        # Use your network to compute log_probs for given state
        log_probs = self.model(states)
        return log_probs
    
    def get_log_probs(self, states):
        '''
        Log-probs for training
        '''
        
        return self.forward(states)
    
    def get_probs(self, states):
        '''
        Probs for interaction
        '''
        
        return torch.exp(self.forward(states))
    
    def act(self, obs, sample=True):
        '''
        Samples action from policy distribution (sample = True) or takes most likely action (sample = False)
        :param: obs - single observation vector
        :param sample: if True, samples from \pi, otherwise takes most likely action
        :returns: action (single integer) and probabilities for all actions
        '''

        probs = self.get_probs(Variable(torch.FloatTensor([obs]))).data.numpy()

        if sample:
            action = int(np.random.choice(n_actions,p=probs[0]))
        else:
            action = int(np.argmax(probs))

        return action, probs[0]

agent = TRPOAgent(observation_shape, n_actions)

# %%
# Check if log-probabilities satisfies all the requirements
log_probs = agent.get_log_probs(Variable(torch.FloatTensor([env.reset()])))
assert isinstance(log_probs, Variable) and log_probs.requires_grad, "qvalues must be a torch variable with grad"
assert len(log_probs.shape) == 2 and log_probs.shape[0] == 1 and log_probs.shape[1] == n_actions
sums = torch.sum(torch.exp(log_probs), dim=1)
assert (0.999<sums).all() and (1.001>sums).all()

# Demo use
print ("sampled:", [agent.act(env.reset()) for _ in range(5)])
print ("greedy:", [agent.act(env.reset(),sample=False) for _ in range(5)])
# Out:
# sampled: [(2, array([0.36368975, 0.1978293 , 0.4384809 ], dtype=float32)), (2, array([0.35584295, 0.19832397, 0.44583312], dtype=float32)), (1, array([0.36027643, 0.19904418, 0.4406794 ], dtype=float32)), (2, array([0.36052316, 0.19713098, 0.44234586], dtype=float32)), (2, array([0.3646132 , 0.19917688, 0.43620992], dtype=float32))]
# greedy: [(2, array([0.35723886, 0.1977964 , 0.44496474], dtype=float32)), (2, array([0.3580753 , 0.20117359, 0.44075117], dtype=float32)), (2, array([0.36440426, 0.19441895, 0.4411768 ], dtype=float32)), (2, array([0.3646331 , 0.19736171, 0.4380052 ], dtype=float32)), (2, array([0.35993996, 0.20152217, 0.43853787], dtype=float32))]

# %% [markdown]
# #### Flat parameters operations
#
# We are going to use it

# %%
def get_flat_params_from(model):
    params = []
    for param in model.parameters():
        params.append(param.data.view(-1))

    flat_params = torch.cat(params)
    return flat_params


def set_flat_params_to(model, flat_params):
    prev_ind = 0
    for param in model.parameters():
        flat_size = int(np.prod(list(param.size())))
        param.data.copy_(
            flat_params[prev_ind:prev_ind + flat_size].view(param.size()))
        prev_ind += flat_size

# %% [markdown]
# Compute cummulative reward just like you did in vanilla REINFORCE

# %%
import scipy.signal
def get_cummulative_returns(r, gamma=1):
    """
    Computes cummulative discounted rewards given immediate rewards
    G_i = r_i + gamma*r_{i+1} + gamma^2*r_{i+2} + ...
    Also known as R(s,a).
    """
    r = np.array(r)
    assert r.ndim >= 1
    return scipy.signal.lfilter([1], [1, -gamma], r[::-1], axis=0)[::-1]

# %%
#simple demo on rewards [0,0,1,0,0,1]
get_cummulative_returns([0,0,1,0,0,1],gamma=0.9)
# Out:
# array([1.40049, 1.5561 , 1.729  , 0.81   , 0.9    , 1.     ])

# %% [markdown]
# **Rollout**

# %%
def rollout(env, agent, max_pathlength=2500, n_timesteps=50000):
    """
    Generate rollouts for training.
    :param: env - environment in which we will make actions to generate rollouts.
    :param: act - the function that can return policy and action given observation.
    :param: max_pathlength - maximum size of one path that we generate.
    :param: n_timesteps - total sum of sizes of all pathes we generate.
    """
    paths = []

    total_timesteps = 0
    while total_timesteps < n_timesteps:
        obervations, actions, rewards, action_probs = [], [], [], []
        obervation = env.reset()
        for _ in range(max_pathlength):
            action, policy = agent.act(obervation)
            obervations.append(obervation)
            actions.append(action)
            action_probs.append(policy)
            obervation, reward, done, _ = env.step(action)
            rewards.append(reward)
            total_timesteps += 1
            if done or total_timesteps==n_timesteps:
                path = {"observations": np.array(obervations),
                        "policy": np.array(action_probs),
                        "actions": np.array(actions),
                        "rewards": np.array(rewards),
                        "cumulative_returns": get_cummulative_returns(rewards),
                       }
                paths.append(path)
                break
    return paths

# %%
paths = rollout(env,agent,max_pathlength=5,n_timesteps=100)
print (paths[-1])
assert (paths[0]['policy'].shape==(5, n_actions))
assert (paths[0]['cumulative_returns'].shape==(5,))
assert (paths[0]['rewards'].shape==(5,))
assert (paths[0]['observations'].shape==(5,)+observation_shape)
assert (paths[0]['actions'].shape==(5,))
print ('It\'s ok')
# Out:
# {'observations': array([[ 9.99515547e-01, -3.11234748e-02,  9.96578762e-01,
#         -8.26484776e-02, -8.00779009e-03,  2.00028666e-02],
#        [ 9.99048580e-01, -4.36111675e-02,  9.99238163e-01,
#         -3.90268379e-02, -1.12957008e-01,  4.07364992e-01],
#        [ 9.98899068e-01, -4.69111112e-02,  9.99989446e-01,
#          4.59428789e-03,  8.16919974e-02,  2.13884074e-02],
#        [ 9.99250475e-01, -3.87103175e-02,  9.99249684e-01,
#          3.87307248e-02, -3.45242760e-05,  3.15099117e-01],
#        [ 9.99459167e-01, -3.28842309e-02,  9.95773390e-01,
#          9.18441894e-02,  5.87162275e-02,  2.09123012e-01]]), 'policy': array([[0.36044553, 0.19859573, 0.44095874],
#        [0.3541378 , 0.18553512, 0.46032703],
#        [0.3578296 , 0.1991212 , 0.44304916],
#        [0.35607213, 0.18931946, 0.45460844],
#        [0.35907745, 0.19266212, 0.44826043]], dtype=float32), 'actions': array([2, 0, 2, 1, 2]), 'rewards': array([-1., -1., -1., -1., -1.]), 'cumulative_returns': array([-5., -4., -3., -2., -1.])}
# It's ok

# %% [markdown]
# ### Step 3: Auxiliary functions
#
# Now let's define the loss functions and something else for actual TRPO training.

# %% [markdown]
# The surrogate reward should be
# $$J_{surr}= {1 \over N} \sum\limits_{i=0}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}A_{\theta_{old}(s_i, a_i)}$$
#
# For simplicity, let's use cummulative returns instead of advantage for now:
# $$J'_{surr}= {1 \over N} \sum\limits_{i=0}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}G_{\theta_{old}(s_i, a_i)}$$
#
# Or alternatively, minimize the surrogate loss:
# $$ L_{surr} = - J'_{surr} $$

# %%
def get_loss(agent, observations, actions, cummulative_returns, old_probs):
    """
    Computes TRPO objective
    :param: observations - batch of observations
    :param: actions - batch of actions
    :param: cummulative_returns - batch of cummulative returns
    :param: old_probs - batch of probabilities computed by old network
    :returns: scalar value of the objective function
    """
    batch_size = observations.shape[0]
    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)
    
    probs_for_actions = probs_all[torch.arange(0, batch_size, out=torch.LongTensor()), actions]
    old_probs_for_actions = old_probs[torch.arange(0, batch_size, out=torch.LongTensor()), actions]
    
    # Compute surrogate loss, aka importance-sampled policy gradient
    Loss = -torch.mean(probs_for_actions / old_probs_for_actions * cummulative_returns)
    
    assert Loss.shape == torch.Size([1])
    return Loss

# %% [markdown]
# We can ascend these gradients as long as our $pi_\theta(a|s)$ satisfies the constraint
# $$E_{s,\pi_{\Theta_{t}}}\Big[KL(\pi(\Theta_{t}, s) \:||\:\pi(\Theta_{t+1}, s))\Big]< \alpha$$
#
#
# where
#
# $$KL(p||q) = E _p log({p \over q})$$

# %%
def get_kl(agent, observations, actions, cummulative_returns, old_probs):
    """
    Computes KL-divergence between network policy and old policy
    :param: observations - batch of observations
    :param: actions - batch of actions
    :param: cummulative_returns - batch of cummulative returns (we don't need it actually)
    :param: old_probs - batch of probabilities computed by old network
    :returns: scalar value of the KL-divergence
    """
    batch_size = observations.shape[0]
    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)
    
    # Compute Kullback-Leibler divergence (see formula above)
    # Note: you need to sum KL and entropy over all actions, not just the ones agent took
    old_log_probs = torch.log(old_probs+1e-10)
    
    kl = torch.mean(torch.sum(probs_all * (log_probs_all - old_log_probs), dim=-1))
    
    assert kl.shape == torch.Size([1])
    assert (kl > -0.0001).all() and (kl < 10000).all()
    return kl

# %%
def get_entropy(agent, observations):
    """
    Computes entropy of the network policy 
    :param: observations - batch of observations
    :returns: scalar value of the entropy
    """
    
    observations = Variable(torch.FloatTensor(observations))

    batch_size = observations.shape[0]
    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)
    
    entropy = torch.sum(-probs_all * log_probs_all) / batch_size
    
    assert entropy.shape == torch.Size([1])
    return entropy

# %% [markdown]
# **Linear search**
#
# TRPO in its core involves ascending surrogate policy gradient constrained by KL divergence.
#
# In order to enforce this constraint, we're gonna use linesearch. You can find out more about it [here](https://en.wikipedia.org/wiki/Linear_search)

# %%
def linesearch(f, x, fullstep, max_kl):
    """
    Linesearch finds the best parameters of neural networks in the direction of fullstep contrainted by KL divergence.
    :param: f - function that returns loss, kl and arbitrary third component.
    :param: x - old parameters of neural network.
    :param: fullstep - direction in which we make search.
    :param: max_kl - constraint of KL divergence.
    :returns:
    """
    max_backtracks = 10
    loss, _, = f(x)
    for stepfrac in .5**np.arange(max_backtracks):
        xnew = x + stepfrac * fullstep
        new_loss, kl = f(xnew)
        actual_improve = new_loss - loss
        if kl.data.numpy()<=max_kl and actual_improve.data.numpy() < 0:
            x = xnew
            loss = new_loss
    return x

# %% [markdown]
# **Conjugate gradients**
#
# Since TRPO includes contrainted optimization, we will need to solve Ax=b using conjugate gradients.
#
# In general, CG is an algorithm that solves Ax=b where A is positive-defined. A is Hessian matrix so A is positive-defined. You can find out more about them [here](https://en.wikipedia.org/wiki/Conjugate_gradient_method)

# %%
from numpy.linalg import inv
def conjugate_gradient(f_Ax, b, cg_iters=10, residual_tol=1e-10):
    """
    This method solves system of equation Ax=b using iterative method called conjugate gradients
    :f_Ax: function that returns Ax
    :b: targets for Ax
    :cg_iters: how many iterations this method should do
    :residual_tol: epsilon for stability
    """
    p = b.clone()
    r = b.clone()
    x = torch.zeros(b.size())
    rdotr = torch.dot(r, r)
    for i in range(cg_iters):
        z = f_Ax(p)
        v = rdotr / (torch.dot(p, z) + 1e-8)
        x += v * p
        r -= v * z
        newrdotr = torch.dot(r, r)
        mu = newrdotr / (rdotr + 1e-8)
        p = r + mu * p
        rdotr = newrdotr
        if rdotr < residual_tol:
            break
    return x

# %%
#This code validates conjugate gradients
A = np.random.rand(8, 8)
A = np.matmul(np.transpose(A), A)

def f_Ax(x):
    return torch.matmul(torch.FloatTensor(A), x.view((-1, 1))).view(-1)

b = np.random.rand(8)

w = np.matmul(np.matmul(inv(np.matmul(np.transpose(A), A)), np.transpose(A)), b.reshape((-1, 1))).reshape(-1)
print (w)
print (conjugate_gradient(f_Ax, torch.FloatTensor(b)).numpy())
# Out:
# [  78.41249889   20.37274826 -126.71417445   50.22354824   -9.29913605
#   -17.553962     -0.43712647   43.97351367]
# [  78.41784      20.373259   -126.72236      50.22645      -9.299679
#   -17.55516      -0.43556094   43.976044  ]

# %% [markdown]
# ### Step 4: training
# In this section we construct the whole update step function.

# %%
def update_step(agent, observations, actions, cummulative_returns, old_probs, max_kl):
    """
    This function does the TRPO update step
    :param: observations - batch of observations
    :param: actions - batch of actions
    :param: cummulative_returns - batch of cummulative returns
    :param: old_probs - batch of probabilities computed by old network
    :param: max_kl - controls how big KL divergence may be between old and new policy every step.
    :returns: KL between new and old policies and the value of the loss function.
    """
    
    # Here we prepare the information
    observations = Variable(torch.FloatTensor(observations))
    actions = torch.LongTensor(actions)
    cummulative_returns = Variable(torch.FloatTensor(cummulative_returns))
    old_probs = Variable(torch.FloatTensor(old_probs))
    
    # Here we compute gradient of the loss function
    loss = get_loss(agent, observations, actions, cummulative_returns, old_probs)
    grads = torch.autograd.grad(loss, agent.parameters())
    loss_grad = torch.cat([grad.view(-1) for grad in grads]).data

    def Fvp(v):
        # Here we compute Fx to do solve Fx = g using conjugate gradients
        # We actually do here a couple of tricks to compute it efficiently
        
        kl = get_kl(agent, observations, actions, cummulative_returns, old_probs)

        grads = torch.autograd.grad(kl, agent.parameters(), create_graph=True)
        flat_grad_kl = torch.cat([grad.view(-1) for grad in grads])

        kl_v = (flat_grad_kl * Variable(v)).sum()
        grads = torch.autograd.grad(kl_v, agent.parameters())
        flat_grad_grad_kl = torch.cat([grad.contiguous().view(-1) for grad in grads]).data

        return flat_grad_grad_kl + v * 0.1
    
    # Here we solveolve Fx = g system using conjugate gradients
    stepdir = conjugate_gradient(Fvp, -loss_grad, 10)

    # Here we compute the initial vector to do linear search
    shs = 0.5 * (stepdir * Fvp(stepdir)).sum(0, keepdim=True)

    lm = torch.sqrt(shs / max_kl)
    fullstep = stepdir / lm[0]

    neggdotstepdir = (-loss_grad * stepdir).sum(0, keepdim=True)
    
    # Here we get the start point
    prev_params = get_flat_params_from(agent)
    
    def get_loss_kl(params):
        # Helper for linear search
        set_flat_params_to(agent, params)
        return [get_loss(agent, observations, actions, cummulative_returns, old_probs),
                get_kl(agent, observations, actions, cummulative_returns, old_probs)]
    
    # Here we find our new parameters
    new_params = linesearch(get_loss_kl, prev_params, fullstep, max_kl)
    
    # And we set it to our network
    set_flat_params_to(agent, new_params)

    return get_loss_kl(new_params)

# %% [markdown]
# ##### Step 5: Main TRPO loop
#
# Here we will train our network!

# %%
import time
from itertools import count
from collections import OrderedDict

max_kl=0.01           #this is hyperparameter of TRPO. It controls how big KL divergence may be between old and new policy every step.
numeptotal = 0        #this is number of episodes that we played.

start_time = time.time()

for i in count(1):

    print ("\n********** Iteration %i ************" % i)

    # Generating paths.
    print("Rollout")
    paths = rollout(env, agent)
    print ("Made rollout")
    
    # Updating policy.
    observations = np.concatenate([path["observations"] for path in paths])
    actions = np.concatenate([path["actions"] for path in paths])
    returns = np.concatenate([path["cumulative_returns"] for path in paths])
    old_probs = np.concatenate([path["policy"] for path in paths])
    
    loss, kl = update_step(agent, observations, actions, returns, old_probs, max_kl)

    #Report current progress
    episode_rewards = np.array([path["rewards"].sum() for path in paths])

    stats = OrderedDict()
    numeptotal += len(episode_rewards)
    stats["Total number of episodes"] = numeptotal
    stats["Average sum of rewards per episode"] = episode_rewards.mean()
    stats["Std of rewards per episode"] = episode_rewards.std()
    stats["Time elapsed"] = "%.2f mins" % ((time.time() - start_time)/60.)
    stats["KL between old and new distribution"] = kl.data.numpy()
    stats["Entropy"] = get_entropy(agent, observations).data.numpy()
    stats["Surrogate loss"] = loss.data.numpy()
    for k, v in stats.items():
        print(k + ": " + " " * (40 - len(k)) + str(v))
    i += 1
# Out:
# ********** Iteration 1 ************
# Rollout
# Made rollout
# Total number of episodes:                 169
# Average sum of rewards per episode:       -294.8934911242604
# Std of rewards per episode:               83.96160304589773
# Time elapsed:                             0.34 mins
# KL between old and new distribution:      [0.00997323]
# Entropy:                                  [0.9314293]
# Surrogate loss:                           [158.72824]
#
# ********** Iteration 2 ************
# Rollout
# Made rollout
# Total number of episodes:                 412
# Average sum of rewards per episode:       -204.76954732510288
# Std of rewards per episode:               58.09262841296452
# Time elapsed:                             0.65 mins
# KL between old and new distribution:      [0.00999227]
# Entropy:                                  [0.8688492]
# Surrogate loss:                           [110.23673]
#
# ********** Iteration 3 ************
# Rollout
# Made rollout
# Total number of episodes:                 722
# Average sum of rewards per episode:       -160.29354838709676
# Std of rewards per episode:               38.72817958361278
# Time elapsed:                             0.95 mins
# KL between old and new distribution:      [0.00997135]
# Entropy:                                  [0.79687107]
# Surrogate loss:                           [84.42486]
#
# ********** Iteration 4 ************
# Rollout
# Made rollout
# Total number of episodes:                 1085
# Average sum of rewards per episode:       -136.74380165289256
# Std of rewards per episode:               40.311773039678265
# Time elapsed:                             1.26 mins
# KL between old and new distribution:      [0.00996996]
# Entropy:                                  [0.7424208]
# Surrogate loss:                           [73.9496]
#
# ********** Iteration 5 ************
# Rollout
# Made rollout
# Total number of episodes:                 1480
# Average sum of rewards per episode:       -125.59240506329114
# Std of rewards per episode:               48.1013007328321
# Time elapsed:                             1.61 mins
# KL between old and new distribution:      [0.00997949]
# Entropy:                                  [0.66226125]
# Surrogate loss:                           [71.69635]
#
# ********** Iteration 6 ************
# Rollout
# Made rollout
# Total number of episodes:                 1895
# Average sum of rewards per episode:       -119.48433734939759
# Std of rewards per episode:               31.937651919060407
# Time elapsed:                             1.93 mins
# KL between old and new distribution:      [0.00998833]
# Entropy:                                  [0.6010724]
# Surrogate loss:                           [63.651638]
#
# ********** Iteration 7 ************
# Rollout
# Made rollout
# Total number of episodes:                 2345
# Average sum of rewards per episode:       -110.11333333333333
# Std of rewards per episode:               29.719399575211995
# Time elapsed:                             2.25 mins
# KL between old and new distribution:      [0.00998889]
# Entropy:                                  [0.5333077]
# Surrogate loss:                           [58.82326]
#
# ********** Iteration 8 ************
# Rollout
# Made rollout
# Total number of episodes:                 2821
# Average sum of rewards per episode:       -104.04621848739495
# Std of rewards per episode:               35.524372719708
# Time elapsed:                             2.54 mins
# KL between old and new distribution:      [0.00999475]
# Entropy:                                  [0.43967637]
# Surrogate loss:                           [57.814884]
#
# ********** Iteration 9 ************
# Rollout
# Made rollout
# Total number of episodes:                 3328
# Average sum of rewards per episode:       -97.62130177514793
# Std of rewards per episode:               31.851457812395488
# Time elapsed:                             2.84 mins
# KL between old and new distribution:      [0.00999752]
# Entropy:                                  [0.40393987]
# Surrogate loss:                           [53.811047]
#
# ********** Iteration 10 ************
# Rollout
# Made rollout
# Total number of episodes:                 3843
# Average sum of rewards per episode:       -96.08932038834952
# Std of rewards per episode:               26.906378182816965
# Time elapsed:                             3.14 mins
# KL between old and new distribution:      [0.00999828]
# Entropy:                                  [0.346866]
# Surrogate loss:                           [51.56594]
#
# ********** Iteration 11 ************
# Rollout
# Made rollout
# Total number of episodes:                 4357
# Average sum of rewards per episode:       -96.28210116731518
# Std of rewards per episode:               40.09788837824797
# Time elapsed:                             3.43 mins
# KL between old and new distribution:      [0.00998981]
# Entropy:                                  [0.30309287]
# Surrogate loss:                           [56.206264]
#
# ********** Iteration 12 ************
# Rollout
# Made rollout
# Total number of episodes:                 4886
# Average sum of rewards per episode:       -93.52551984877127
# Std of rewards per episode:               40.62423837836698
# Time elapsed:                             3.73 mins
# KL between old and new distribution:      [0.00999047]
# Entropy:                                  [0.2419622]
# Surrogate loss:                           [55.289623]
#
# ********** Iteration 13 ************
# Rollout
# Made rollout
# Total number of episodes:                 5441
# Average sum of rewards per episode:       -89.0954954954955
# Std of rewards per episode:               34.11416811525566
# Time elapsed:                             4.03 mins
# KL between old and new distribution:      [0.00998002]
# Entropy:                                  [0.21259433]
# Surrogate loss:                           [50.883335]
#
# ********** Iteration 14 ************
# Rollout
# Made rollout
# Total number of episodes:                 5996
# Average sum of rewards per episode:       -89.0954954954955
# Std of rewards per episode:               35.79717485301301
# Time elapsed:                             4.32 mins
# KL between old and new distribution:      [0.00999622]
# Entropy:                                  [0.19461812]
# Surrogate loss:                           [51.53009]
#
# ********** Iteration 15 ************
# Rollout
# Made rollout
# Total number of episodes:                 6536
# Average sum of rewards per episode:       -91.5962962962963
# Std of rewards per episode:               35.10624067642001
# Time elapsed:                             4.63 mins
# KL between old and new distribution:      [0.00999041]
# Entropy:                                  [0.23450536]
# Surrogate loss:                           [52.309128]
#
# ********** Iteration 16 ************
# Rollout
# Made rollout
# Total number of episodes:                 7077
# Average sum of rewards per episode:       -91.42698706099816
# Std of rewards per episode:               37.99047370592977
# Time elapsed:                             4.92 mins
# KL between old and new distribution:      [0.00999216]
# Entropy:                                  [0.2412146]
# Surrogate loss:                           [53.336384]
#
# ********** Iteration 17 ************
# Rollout
# Made rollout
# Total number of episodes:                 7634
# Average sum of rewards per episode:       -88.77019748653501
# Std of rewards per episode:               33.91198305547076
# Time elapsed:                             5.22 mins
# KL between old and new distribution:      [0.00999484]
# Entropy:                                  [0.2066556]
# Surrogate loss:                           [50.658497]
#
# ********** Iteration 18 ************
# Rollout
# Made rollout
# Total number of episodes:                 8199
# Average sum of rewards per episode:       -87.49734513274336
# Std of rewards per episode:               29.273360568431137
# Time elapsed:                             5.52 mins
# KL between old and new distribution:      [0.00999315]
# Entropy:                                  [0.1762048]
# Surrogate loss:                           [48.441177]
#
# ********** Iteration 19 ************
# Rollout
# Made rollout
# Total number of episodes:                 8765
# Average sum of rewards per episode:       -87.34098939929329
# Std of rewards per episode:               27.743053408892305
# Time elapsed:                             5.82 mins
# KL between old and new distribution:      [0.0099772]
# Entropy:                                  [0.1610068]
# Surrogate loss:                           [47.91188]
#
# ********** Iteration 20 ************
# Rollout
# Made rollout
# Total number of episodes:                 9342
# Average sum of rewards per episode:       -85.65684575389947
# Std of rewards per episode:               25.08598922138364
# Time elapsed:                             6.12 mins
# KL between old and new distribution:      [0.00999739]
# Entropy:                                  [0.16344707]
# Surrogate loss:                           [46.345108]
#
# ********** Iteration 21 ************
# Rollout
# Made rollout
# Total number of episodes:                 9899
# Average sum of rewards per episode:       -88.77019748653501
# Std of rewards per episode:               32.824012132772815
# Time elapsed:                             6.43 mins
# KL between old and new distribution:      [0.0099884]
# Entropy:                                  [0.14454041]
# Surrogate loss:                           [50.249435]
#
# ********** Iteration 22 ************
# Rollout
# Made rollout
# Total number of episodes:                 10467
# Average sum of rewards per episode:       -87.03169014084507
# Std of rewards per episode:               31.033983802672683
# Time elapsed:                             6.75 mins
# KL between old and new distribution:      [0.00998301]
# Entropy:                                  [0.13010214]
# Surrogate loss:                           [48.871445]
#
# ********** Iteration 23 ************
# Rollout
# Made rollout
# Total number of episodes:                 11053
# Average sum of rewards per episode:       -84.3259385665529
# Std of rewards per episode:               23.088150771128372
# Time elapsed:                             7.06 mins
# KL between old and new distribution:      [0.00998743]
# Entropy:                                  [0.1644781]
# Surrogate loss:                           [45.135647]
#
# ********** Iteration 24 ************
# Rollout
# Made rollout
# Total number of episodes:                 11641
# Average sum of rewards per episode:       -84.03571428571429
# Std of rewards per episode:               24.470663054771034
# Time elapsed:                             7.37 mins
# KL between old and new distribution:      [0.00998154]
# Entropy:                                  [0.14346531]
# Surrogate loss:                           [45.451283]
#
# ********** Iteration 25 ************
# Rollout
# Made rollout
# Total number of episodes:                 12223
# Average sum of rewards per episode:       -84.91408934707904
# Std of rewards per episode:               28.04162665654904
# Time elapsed:                             7.68 mins
# KL between old and new distribution:      [0.00997798]
# Entropy:                                  [0.16002586]
# Surrogate loss:                           [46.889805]
#
# ********** Iteration 26 ************
# Rollout
# Made rollout
# Total number of episodes:                 12792
# Average sum of rewards per episode:       -86.87697715289983
# Std of rewards per episode:               31.70435119524216
# Time elapsed:                             7.98 mins
# KL between old and new distribution:      [0.00998909]
# Entropy:                                  [0.12579067]
# Surrogate loss:                           [49.005234]
#
# ********** Iteration 27 ************
# Rollout
# Made rollout
# Total number of episodes:                 13366
# Average sum of rewards per episode:       -86.10975609756098
# Std of rewards per episode:               26.541601208556177
# Time elapsed:                             8.28 mins
# KL between old and new distribution:      [0.00999588]
# Entropy:                                  [0.12115957]
# Surrogate loss:                           [46.994972]
#
# ********** Iteration 28 ************
# Rollout
# Made rollout
# Total number of episodes:                 13959
# Average sum of rewards per episode:       -83.32040472175379
# Std of rewards per episode:               26.12840013465692
# Time elapsed:                             8.58 mins
# KL between old and new distribution:      [0.00997472]
# Entropy:                                  [0.10614863]
# Surrogate loss:                           [45.573277]
#
# ********** Iteration 29 ************
# Rollout
# Made rollout
# Total number of episodes:                 14509
# Average sum of rewards per episode:       -89.91454545454546
# Std of rewards per episode:               34.92394291069884
# Time elapsed:                             8.95 mins
# KL between old and new distribution:      [0.00999864]
# Entropy:                                  [0.11574906]
# Surrogate loss:                           [51.481564]
#
# ********** Iteration 30 ************
# Rollout
# Made rollout
# Total number of episodes:                 15075
# Average sum of rewards per episode:       -87.34275618374558
# Std of rewards per episode:               33.3720197991919
# Time elapsed:                             9.25 mins
# KL between old and new distribution:      [0.00996785]
# Entropy:                                  [0.10980327]
# Surrogate loss:                           [49.83832]
#
# ********** Iteration 31 ************
# Rollout
# Made rollout
# Total number of episodes:                 15670
# Average sum of rewards per episode:       -83.03529411764706
# Std of rewards per episode:               23.02495025308833
# Time elapsed:                             9.59 mins
# KL between old and new distribution:      [0.00998073]
# Entropy:                                  [0.09430281]
# Surrogate loss:                           [44.588047]
#
# ********** Iteration 32 ************
# Rollout
# Made rollout
# Total number of episodes:                 16259
# Average sum of rewards per episode:       -83.893039049236
# Std of rewards per episode:               26.42689443555207
# Time elapsed:                             9.89 mins
# KL between old and new distribution:      [0.00998535]
# Entropy:                                  [0.08313739]
# Surrogate loss:                           [45.990448]
#
# ********** Iteration 33 ************
# Rollout
# Made rollout
# Total number of episodes:                 16843
# Average sum of rewards per episode:       -84.6181506849315
# Std of rewards per episode:               22.817615446453328
# Time elapsed:                             10.19 mins
# KL between old and new distribution:      [0.00999964]
# Entropy:                                  [0.08886241]
# Surrogate loss:                           [45.28556]
#
# ********** Iteration 34 ************
# Rollout
# Made rollout
# Total number of episodes:                 17439
# Average sum of rewards per episode:       -82.89597315436242
# Std of rewards per episode:               28.731561065040978
# Time elapsed:                             10.50 mins
# KL between old and new distribution:      [0.009981]
# Entropy:                                  [0.07639478]
# Surrogate loss:                           [46.24934]
#
# ********** Iteration 35 ************
# Rollout
# Made rollout
# Total number of episodes:                 18018
# Average sum of rewards per episode:       -85.35751295336787
# Std of rewards per episode:               23.569138907488874
# Time elapsed:                             10.80 mins
# KL between old and new distribution:      [0.009986]
# Entropy:                                  [0.07570986]
# Surrogate loss:                           [45.82158]
#
# ********** Iteration 36 ************
# Rollout
# Made rollout
# Total number of episodes:                 18596
# Average sum of rewards per episode:       -85.50865051903114
# Std of rewards per episode:               28.867267437718617
# Time elapsed:                             11.10 mins
# KL between old and new distribution:      [0.00998121]
# Entropy:                                  [0.07749698]
# Surrogate loss:                           [47.478844]
#
# ********** Iteration 37 ************
# Rollout
# Made rollout
# Total number of episodes:                 19175
# Average sum of rewards per episode:       -85.35924006908463
# Std of rewards per episode:               31.87256788962043
# Time elapsed:                             11.40 mins
# KL between old and new distribution:      [0.00999652]
# Entropy:                                  [0.06925146]
# Surrogate loss:                           [48.4663]
#
# ********** Iteration 38 ************
# Rollout
# Made rollout
# Total number of episodes:                 19724
# Average sum of rewards per episode:       -90.0783242258652
# Std of rewards per episode:               33.83285907924327
# Time elapsed:                             11.74 mins
# KL between old and new distribution:      [0.00957567]
# Entropy:                                  [0.06853059]
# Surrogate loss:                           [51.23355]
#
# ********** Iteration 39 ************
# Rollout
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-1849c715f773> in <module>()
#      14     # Generating paths.
#      15     print("Rollout")
# ---> 16     paths = rollout(env, agent)
#      17     print ("Made rollout")
#      18
#
# <ipython-input-10-82275eb0132c> in rollout(env, agent, max_pathlength, n_timesteps)
#      18             actions.append(action)
#      19             action_probs.append(policy)
# ---> 20             obervation, reward, done, _ = env.step(action)
#      21             rewards.append(reward)
#      22             total_timesteps += 1
#
# ~/Documents/Practical_RL/venv/lib/python3.6/site-packages/gym/wrappers/time_limit.py in step(self, action)
#      29     def step(self, action):
#      30         assert self._episode_started_at is not None, "Cannot call env.step() before calling reset()"
# ---> 31         observation, reward, done, info = self.env.step(action)
#      32         self._elapsed_steps += 1
#      33
#
# ~/Documents/Practical_RL/venv/lib/python3.6/site-packages/gym/envs/classic_control/acrobot.py in step(self, a)
#     112         s_augmented = np.append(s, torque)
#     113
# --> 114         ns = rk4(self._dsdt, s_augmented, [0, self.dt])
#     115         # only care about final timestep of integration returned by integrator
#     116         ns = ns[-1]
#
# ~/Documents/Practical_RL/venv/lib/python3.6/site-packages/gym/envs/classic_control/acrobot.py in rk4(derivs, y0, t, *args, **kwargs)
#     296         k2 = np.asarray(derivs(y0 + dt2 * k1, thist + dt2, *args, **kwargs))
#     297         k3 = np.asarray(derivs(y0 + dt2 * k2, thist + dt2, *args, **kwargs))
# --> 298         k4 = np.asarray(derivs(y0 + dt * k3, thist + dt, *args, **kwargs))
#     299         yout[i + 1] = y0 + dt / 6.0 * (k1 + 2 * k2 + 2 * k3 + k4)
#     300     return yout
#
# ~/Documents/Practical_RL/venv/lib/python3.6/site-packages/gym/envs/classic_control/acrobot.py in _dsdt(self, s_augmented, t)
#     154         dtheta2 = s[3]
#     155         d1 = m1 * lc1 ** 2 + m2 * \
# --> 156             (l1 ** 2 + lc2 ** 2 + 2 * l1 * lc2 * np.cos(theta2)) + I1 + I2
#     157         d2 = m2 * (lc2 ** 2 + l1 * lc2 * np.cos(theta2)) + I2
#     158         phi2 = m2 * lc2 * g * np.cos(theta1 + theta2 - np.pi / 2.)
#
# KeyboardInterrupt:

# %% [markdown]
# # Homework option I: better sampling (10+pts)
#
# In this section, you're invited to implement a better rollout strategy called _vine_.
#
# ![img](https://s17.postimg.org/i90chxgvj/vine.png)
#
# In most gym environments, you can actually backtrack by using states. You can find a wrapper that saves/loads states in [the mcts seminar](https://github.com/yandexdataschool/Practical_RL/blob/master/yet_another_week/seminar_MCTS.ipynb).
#
# You can read more about in the [TRPO article](https://arxiv.org/abs/1502.05477) in section 5.2.
#
# The goal here is to implement such rollout policy (we recommend using tree data structure like in the seminar above).
# Then you can assign cummulative rewards similar to `get_cummulative_rewards`, but for a tree.
#
# __bonus task__ - parallelize samples using multiple cores

# %% [markdown]
# # Homework option II (10+pts)
#
# Let's use TRPO to train evil robots! (pick any of two)
# * [MuJoCo robots](https://gym.openai.com/envs#mujoco)
# * [Box2d robot](https://gym.openai.com/envs/BipedalWalker-v2)
#
# The catch here is that those environments have continuous action spaces.
#
# Luckily, TRPO is a policy gradient method, so it's gonna work for any parametric $\pi_\theta(a|s)$. We recommend starting with gaussian policy:
#
# $$\pi_\theta(a|s) = N(\mu_\theta(s),\sigma^2_\theta(s)) = {1 \over \sqrt { 2 \pi {\sigma^2}_\theta(s) } } e^{ (a -
# \mu_\theta(s))^2 \over 2 {\sigma^2}_\theta(s) } $$
#
# In the $\sqrt { 2 \pi {\sigma^2}_\theta(s) }$ clause, $\pi$ means ~3.1415926, not agent's policy.
#
# This essentially means that you will need two output layers:
# * $\mu_\theta(s)$, a dense layer with linear activation
# * ${\sigma^2}_\theta(s)$, a dense layer with activation tf.exp (to make it positive; like rho from bandits)
#
# For multidimensional actions, you can use fully factorized gaussian (basically a vector of gaussians).
#
# __bonus task__: compare performance of continuous action space method to action space discretization
